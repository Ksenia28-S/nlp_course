# %% [markdown]
# <font color=red>**Danger zone:**</font> you'll be fine-tuning a model to generate positive, negative or even toxic reviews. We'll be doing this for fun, but this is also the technique for [review bombing](https://en.wikipedia.org/wiki/Review_bomb), bot farms on social media and other less than dignified stuff. It is ultimately your decision how you apply this knowledge, but before you choose, ask yourself: is this why you chose to learn ML?
#
#
# # LLMs Alignment with Reinforcement Learning from human feedback (RLHF).
#
# _based on the [original notebook](https://github.com/antndlcrx/oxford-llms-workshop/blob/main/materials/seminars/day_3/8_LLMs%20alignment%20with%20RLHF.ipynb) by Ilya Boytsov for the Oxford LLMs workshop_

# %% [markdown]
# In this session, you're gonna fine-tune a language model with reinforcement learning to make it generate good (or bad) reviews.
#
# To perform RL-based fine-tuning, we'll use a new (in this course) library called [Transformer Reinforcement Learning (TRL)](https://huggingface.co/docs/trl). TRL implements the main reinforcement learning components of RLHF: reward modeling and fine-tuning with PPO.
#
# ![img](https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/TRL-readme.png)

# %%
# %pip install -q trl==0.7.4 transformers==4.33.1 datasets==2.14.4 peft==0.5.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 21.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 34.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 35.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 63.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 22.6 MB/s eta 0:00:00

# %% [markdown]
# ### Tutorial: align the model to generate positive movie reviews
#
# To see how TRL works, we'll use it to align GPT2 on IMDB dataset to generate positive (or negative) movie reviews. In fact, __it's your choice whether you want positive or negative reviews.__
#
# But before you choose, let's take a look at the baseline model: a GPT-2 fine-tuned on generating arbitrary movie reviews.

# %%
import torch
import transformers
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
main_tokenizer = transformers.AutoTokenizer.from_pretrained("lvwerra/gpt2-imdb")
main_model = transformers.AutoModelForCausalLM.from_pretrained("lvwerra/gpt2-imdb", device_map=device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
inputs = main_tokenizer("The movie", return_tensors='pt').to(device)
generated_ids = main_model.generate(**inputs, max_new_tokens=50, do_sample=True)
print("\nGenerated text:", main_tokenizer.decode(generated_ids.flatten().cpu().numpy().tolist()))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated text: The movie makes great entertainment with the best actors all around<|endoftext|>

# %% [markdown]
# If you run this cell a couple of times, you'll see that the model generates both positive, negative and neutral reviews in some proportion. What we're gonna do next is teach the model to generate more positive (or negative) reviews.
#
# Similarly to InstructGPT, we're gonna do that in 2 stages:
# - **train a reward model** to assign higher values to positive (or negative) reviews
# - fine-tune the language model to **maximize that reward using [proximal policy optimization](https://openai.com/research/openai-baselines-ppo)**

# %% [markdown]
# ## Stage 1: train a reward model
#
# First, we'll train a BERT-like model as our reward model. We'll generate a synthetic pairwise rankings to emulate human rankings.
#
# __Q:__ why do I need a reward model? Can I just use a pre-trained sentiment classifier? <br> __A:__ Yes, you can - but that only works for movie reviews. But this tutorial will teach you how to do RLHF for any kind objective.
#
#
# __If you actually want to maximize sentiment (or other "label") instead of human preferences, train reward model as a classifier! (see week5)__

# %%
# We'll be fine-tuning a small BERT-like model for now. Please try other models for the main assignment.
reward_model = transformers.AutoModelForSequenceClassification.from_pretrained("distilbert-base-cased", device_map=device)
reward_tokenizer = transformers.AutoTokenizer.from_pretrained("distilbert-base-cased")
# Out:
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['pre_classifier.weight', 'classifier.weight', 'pre_classifier.bias', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %% [markdown]
# __Note that__ the reward model has a separate tokenizer, different from the main model. They don't need to be the same for RLHF fine-tuning.

# %%
# To train a reward model, you need a dataset (or generator) of positive-negative pairs.
# Each training sample should be a dict with 4 keys:
#  - input_ids_chosen, attention_mask_chosen = tokenizer("A sentence that human labeler likes more")
#  - input_ids_rejected, attention_mask_rejected = tokenizer("A sentence that human labeler likes less")

import torch
import datasets

class IMDBPairwiseDataset(torch.utils.data.Dataset):
    """ A dataset of all possible pairs of chosen and texts in TRT reward training format """
    def __init__(self, imdb, tokenizer, accepted_label: int):
        super().__init__()
        self.tokenizer = tokenizer
        self.chosen_texts = [row['text'] for row in imdb if row['label'] == accepted_label]
        self.rejected_texts = [row['text'] for row in imdb if row['label'] != accepted_label]
        assert self.chosen_texts, f"no texts with label {accepted_label}"
        print(f"Found {len(self.chosen_texts)} chosen and {len(self.rejected_texts)} rejected texts, {len(self)} pairs")

    def __len__(self):
        return len(self.chosen_texts) * len(self.rejected_texts)  # all pairs

    def __getitem__(self, index: int):
        chosen = self.tokenizer(self.chosen_texts[index // len(self.chosen_texts)], truncation=True)
        rejected = self.tokenizer(self.rejected_texts[index % len(self.chosen_texts)], truncation=True)
        return dict(input_ids_chosen=chosen['input_ids'], attention_mask_chosen=chosen['attention_mask'],
                    input_ids_rejected=rejected['input_ids'], attention_mask_rejected=rejected['attention_mask'])

# %%
TARGET_LABEL = 0   # and make sure it works by reviewing the sample printed below
imdb = datasets.load_dataset("imdb", split='train')
reward_data = IMDBPairwiseDataset(imdb, reward_tokenizer, accepted_label=TARGET_LABEL)

sample = reward_data[31337]
print('CHOSEN:', reward_tokenizer.decode(sample['input_ids_chosen']))
print('REJECTED:', reward_tokenizer.decode(sample['input_ids_rejected']))
# Out:
# Downloading builder script:   0%|          | 0.00/4.31k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.17k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.59k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/84.1M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Found 12500 chosen and 12500 rejected texts, 156250000 pairs
# CHOSEN: [CLS] If only to avoid making this type of film in the future. This film is interesting as an experiment but tells no cogent story. < br / > < br / > One might feel virtuous for sitting thru it because it touches on so many IMPORTANT issues but it does so without any discernable motive. The viewer comes away with no new perspectives ( unless one comes up with one while one's mind wanders, as it will invariably do during this pointless film ). < br / > < br / > One might better spend one's time staring out a window at a tree growing. < br / > < br / > [SEP]
# REJECTED: [CLS] This movie has some things that are pretty amazing. First, it is supposed to be based on a true story. That, in itself, is amazing that multiple tornadoes would hit the same town at night in the fall - in Nebraska. I wonder if the real town's name was close to " Blainsworth " ( which is the town's name in the movie ). There is an Ainsworth, Nebraska, but there is also a town that starts with Blains - something. < br / > < br / > It does show the slowest moving tornadoes on record in the the seen where the boys are in the house. On the other hand, the scene where the TV goes fuzzy is based in fact. Before Doppler radar and weather radio, we were taught that if you turned your TV to a particular channel ( not on cable ) and tuned the brightness just right, you could tell if there was a tornado coming. The problem was that by then you would be able to hear it. < br / > < br / > Since I know something about midwest tornadoes, it made this movie fun for me. I enjoy it more than Twister. I mean, give me a break - there is no way you could make it through and F5 by chaining yourself to a pipe in a well house. [SEP]

# %% [markdown]
# We'll be using `trl.RewardTrainer` - a special case of `transformers.Trainer` that you used in the past. `RewardTrainer` accepts the same format of training arguments (e.g. batch size, gradient checkpointing) as before, except that it trains the model for the pairwise reward objective from [the InstructGPT paper](https://arxiv.org/pdf/2203.02155.pdf):
#
# ![img](https://i.imgur.com/2JzNAPs.png)
#
# Note that the model itself does not score pairs: it processes chosen ($y_w$) and rejected ($y_l$) samples independently. To minimize this loss, the reward model needs to score chosen sample higher than the rejected one. Note that the formula also assumes some context $x$, which is useful for seq2seq tasks. In our case of movie reviews, $x$ is empty.

# %%
import trl

training_args = trl.RewardConfig(  # like transformers.TrainingArguments
    output_dir="reward_model",
    per_device_train_batch_size=32,
    gradient_accumulation_steps=1,
    learning_rate=1.41e-5,
    max_steps=1_000,              # note: training may need more than 1k steps
    logging_steps=50,
    gradient_checkpointing=True,  # reduce memory usage but train ~30% slower
    gradient_checkpointing_kwargs={"use_reentrant": False},
    fp16=True                     # disable this on CPU or on very old GPUs
    # you may add any other hyperparameters that you found useful in weeks 5-7
)

trainer = trl.RewardTrainer(
    model=reward_model,
    args=training_args,
    tokenizer=reward_tokenizer,
    train_dataset=reward_data,
    peft_config=None,  # optionally, you may tune with LoRA, prompt-tuning, etc
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/reward_trainer.py:174: UserWarning: When using RewardDataCollatorWithPadding, you should set `max_length` in RewardConfig. It will be set to `512` by default, but you should do it yourself in the future.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/reward_trainer.py:191: UserWarning: When using RewardDataCollatorWithPadding, you should set `remove_unused_columns=False` in your RewardConfig we have set it for you, but you should do it yourself in the future.
#   warnings.warn(
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2436: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
#     <div>
#
#       <progress value='1000' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1000 24:08, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.518200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.189200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.137400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.118100</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.094400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.105400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.090700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.087700</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.083700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.081600</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.087100</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.061800</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.058600</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.078300</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.070900</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.048700</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.060200</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.066300</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.061500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.047300</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2436: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# TrainOutput(global_step=1000, training_loss=0.10734328007698059, metrics={'train_runtime': 1462.9196, 'train_samples_per_second': 21.874, 'train_steps_per_second': 0.684, 'total_flos': 0.0, 'train_loss': 0.10734328007698059, 'epoch': 0.0})

# %%
reward_model.gradient_checkpointing_disable()
reward_model.eval()
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ### Sanity-check the reward model (1 point)
#
# Let's check how our reward model performs.
#
# __Your task__ is to measure how often does your reward model can rank a pair of (chosen and rejected) reviews correctly. Please measure this separately for train data (`imdb`) and a separate test set loaded below.

# %%
for sample_index in 45, 16000:
  print('TEXT:', imdb[sample_index]['text'])
  inputs = reward_tokenizer(
      imdb[sample_index]['text'], truncation=True, return_tensors='pt').to(device)
  with torch.no_grad():
    reward = reward_model(**inputs).logits[0, 0].item()
    print("REWARD:", reward)
  print('LABEL:', imdb[sample_index]['label'])
  print()

# note: your reward model may produce different absolute rewards.
# This is fine as long as the rewards are ordered correctly (most of the time)
# Out:
# TEXT: This movie sucked. It really was a waste of my life. The acting was atrocious, the plot completely implausible. Long, long story short, these people get "terrorized" by this pathetic "crazed killer", but completely fail to fight back in any manner. And this is after they take a raft on a camping trip, with no gear, and show up at a campsite that is already assembled and completely stocked with food and clothes and the daughters headphones. Additionally, after their boat goes missing, they panic that they're stuck in the woods, but then the daughters boyfriend just shows up and they apparently never consider that they could just hike out of the woods like he did to get to them. Like I said, this movie sucks. A complete joke. Don't let your girlfriend talk you into watching it.
# REWARD: 4.9375
# LABEL: 0
#
# TEXT: Good: Engaging cinematic firefights, great presentation, vehicles are actually fun to drive, fairly appealing multiplayer, faithful to the movie, and the list goes on.<br /><br />Bad: Main missions are a bit short.<br /><br />This game defines what a "good" third person shooter(not necessarily a spy-game) is. Great firefights carry on the story and make you want to complete EVERY single mission through, and unlock all the genuine bonuses the game has to offer. The hype this game had, was lived up to, and I personally think you should buy it, and hook up with a couple of friends and play this one. Loads of fun. <br /><br />The sound in this game, is a rip-roaring achievement from a few previous bond games, and firing a weapon, really feels like you're firing a weapon. It ties in with the aspect that you are a deadly and ruthless spy.<br /><br />All in all, this game makes you excited and satisfied after you make it through, and some multiplayer that can compete with the standards of the crafty James Bond "Nightfire" game for gamecube.
# REWARD: -4.80078125
# LABEL: 1

# %%
from tqdm import tqdm

# Calculate reward for every text in imdb training part

rewards = []
for index in tqdm(range(len(imdb))):
    text = imdb[index]['text']
    label = imdb[index]['label']
    inputs = reward_tokenizer(text, truncation=True, return_tensors='pt').to(device)

    with torch.no_grad():
        reward = reward_model(**inputs).logits[0, 0].item()
    rewards.append(reward)

imdb = imdb.add_column("reward", rewards)
# Out:
# 100%|██████████| 25000/25000 [05:08<00:00, 81.06it/s]

# %%
from itertools import product

correct_train = 0
total_train = (len(imdb) // 2)**2

# Create lists with rewards for both labels
chosen_rew = [imdb[i]['reward'] for i in range(len(imdb)) if imdb[i]['label'] == 0]
rejected_rew = [imdb[i]['reward'] for i in range(len(imdb)) if imdb[i]['label'] != 0]

# Look at all pairs, compare the elements and update count
for chosen, rejected in tqdm(product(chosen_rew, rejected_rew)):
    if chosen > rejected:
        correct_train += 1

accuracy = correct_train / total_train
print(f"\nTraining Accuracy: {accuracy * 100:.2f}%")
# Out:
# 156250000it [01:54, 1361669.13it/s]
# Training Accuracy: 98.28%

# %%
imdb_test = datasets.load_dataset("imdb", split='test')

# Calculate reward for every text in imdb test part

rewards = []
for index in tqdm(range(len(imdb_test))):
    text = imdb_test[index]['text']
    label = imdb_test[index]['label']
    inputs = reward_tokenizer(text, truncation=True, return_tensors='pt').to(device)

    with torch.no_grad():
        reward = reward_model(**inputs).logits[0, 0].item()
    rewards.append(reward)

imdb_test = imdb_test.add_column("reward", rewards)
# Out:
# 100%|██████████| 25000/25000 [05:17<00:00, 78.78it/s]

# %%
from itertools import product

correct_test = 0
total_test = (len(imdb_test) // 2)**2

# Create lists with rewards for both labels
chosen_rew = [imdb_test[i]['reward'] for i in range(len(imdb_test)) if imdb_test[i]['label'] == 0]
rejected_rew = [imdb_test[i]['reward'] for i in range(len(imdb_test)) if imdb_test[i]['label'] != 0]

# Look at all pairs, compare the elements and update count
for chosen, rejected in tqdm(product(chosen_rew, rejected_rew)):
    if chosen > rejected:
        correct_test += 1

accuracy = correct_test / total_test
print(f"\nTesting Accuracy: {accuracy * 100:.2f}%")
# Out:
# 156250000it [01:07, 2313112.05it/s]
# Testing Accuracy: 97.28%

# %% [markdown]
# ### Reward-guided generation (1 point)
#
# If you did everything right, by now you should have a decent reward model. Before we use it for reinforcement learning, let's see if we can align model samples without any training.
#
# To do so, you can use reward-guided inference: __generate N=16 samples, then select the one with the highest reward__ (according to your reward model).
#
# For this problem, it's on you to demonstrate whether or not your code works. Find at least 5 neutral prompts such as "This movie is" (...), generate samples, rank them based on reward and show which samples get the highest reward.
#
# Note: it is faster to generate samples in parallel, rather than sequentially, as follows:

# %%
inputs = main_tokenizer(["It was"] * 5, return_tensors='pt').to(device)
for candidate in main_model.generate(**inputs, max_new_tokens=50, do_sample=True):
  print("Sample:", main_tokenizer.decode(candidate.flatten().cpu().numpy().tolist()))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample: It was also filmed on stage with actors from other movies, although some, like "Babylon 5" and "The Patriot", feature characters of different nationalities. All told, it's an interesting and well-written film, and one of films where
# Sample: It was hard to believe that the film would be made on DVD by a company that was trying to build up "Star Trek IV: The Voyage Home", which became a successful franchise and is quite successful after so many great movies.<br /><br />
# Sample: It was like the second time you watch TV in the world. But you are bored and want a movie.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Sample: It was a good movie. Not only is it a well-acted comedy, it's also very strong. For the first twenty minutes we're all in this movie and the suspense builds up as the movie goes along--until somebody catches it on the DVD.
# Sample: It was funny that someone would think this film would be funny or funny, it was simply a comedy. Maybe my opinion wasn't clear, but I don't think there is a film or a book on this subject that would make me laugh or cringe. So

# %%
# <YOUR CODE HERE> - feel free to organize it as you see fit

from torch.nn.functional import softmax

# 7 neutral prompts
neutral_prompts = [
    "This movie is",
    "The film was",
    "I watched a movie and",
    "In my opinion, the movie",
    "After watching the film, I feel",
    "The dialogue in the film",
    "My impression of the movie is"
]

# Generate samples
generated_samples = []

for prompt in neutral_prompts:
    inputs = main_tokenizer([prompt] * 16, return_tensors='pt').to(device)
    candidates = main_model.generate(**inputs, max_new_tokens=50, do_sample=True)
    generated_samples.extend(candidates)

# Calculate rewards for each generated sample
with torch.no_grad():
    rewards = []
    for sample in generated_samples:
        inputs = reward_tokenizer(main_tokenizer.decode(sample), truncation=True, return_tensors='pt').to(device)
        reward = reward_model(**inputs).logits[0, 0].item()
        rewards.append(reward)

# Rank samples based on rewards and display
ranked_samples = sorted(zip(generated_samples, rewards), key=lambda x: x[1], reverse=True)

for rank, (sample, reward) in enumerate(ranked_samples, start=1):
    print(f"Rank {rank} - Reward: {reward:.4f}")
    print("Sample:", main_tokenizer.decode(sample.flatten().cpu().numpy().tolist()))
    print("-" * 50)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Rank 1 - Reward: 4.8633
# Sample: I watched a movie and this movie should stop. The script is awful, which is exactly what I expected to have for a documentary. The acting is absolutely appalling. The film tries to show how poor the people of "The Green Menace" were with an evil empire on
# --------------------------------------------------
# Rank 2 - Reward: 4.7695
# Sample: This movie is so boring and unoriginal it should be banned. It is not even about the characters that I think are all so important to watch. All in all this movie does nothing if you want to watch a movie that tells a real story without talking about it
# --------------------------------------------------
# Rank 3 - Reward: 4.7539
# Sample: This movie is bad. Bad bad. It makes little sense why people get angry about it after the whole thing, and that makes no sense at all. If you are a woman and you think you can be good, you'll be glad to hear this stupid movie
# --------------------------------------------------
# Rank 4 - Reward: 4.7344
# Sample: The dialogue in the film is just awful. The action is pretty slow, and the main actor is just annoying. The soundtrack is too much for this director - I can't even get the title for the song in my head. I think he'd better go back and add
# --------------------------------------------------
# Rank 5 - Reward: 4.7109
# Sample: In my opinion, the movie was not too bad, but the ending is not good by any means. The movie's acting is so bad it could be considered as "horrible." The only problem I'm having is a feeling I didn't get from the opening credits. Just
# --------------------------------------------------
# Rank 6 - Reward: 4.6953
# Sample: The film was only a dream...it wasn't a movie. It was just a very bad movie. All it has in common is a very bad ending that leaves the viewer wondering what else they can do with this movie. I am going to give all the references
# --------------------------------------------------
# Rank 7 - Reward: 4.6836
# Sample: My impression of the movie is how badly it has been misconstrued and should be forgiven. It's such a weak story, in my opinion. It takes so long to work because the acting is so lacking in plot and the directing is so terrible. The ending is boring,
# --------------------------------------------------
# Rank 8 - Reward: 4.6602
# Sample: This movie is a total mess, as if it was trying terribly hard to explain why this particular character was there. I think that the acting was so bad that I couldn't stop shaking my head.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# --------------------------------------------------
# Rank 9 - Reward: 4.6250
# Sample: After watching the film, I feel sorry for everyone involved with the production.<br /><br />The acting is horrible. The editing looks bad like they are taking a vacation. The editing scenes look bad, the actors look pathetic.<br /><br />Some people didn't learn
# --------------------------------------------------
# Rank 10 - Reward: 4.5742
# Sample: The dialogue in the film was absolutely terrible, and there were practically no lines of dialogue! In fact, I find this movie so boring it could be hard to breathe - a whole lot more nonsense, and you know we have the same plot - a bunch of characters have been
# --------------------------------------------------
# Rank 11 - Reward: 4.5664
# Sample: This movie is so bad they just don't work with it and it just is. If a girl in college were to tell her life at the end she said, that is more likely that she'd have ended up in a worse hospital.<br /><br />
# --------------------------------------------------
# Rank 12 - Reward: 4.4844
# Sample: This movie is full of humor and I would have gladly left that film. It's fun stuff. However, it lacks most of the charm and the story is a mess. There are a few good jokes that get thrown out of the script and then forgotten, but
# --------------------------------------------------
# Rank 13 - Reward: 4.4570
# Sample: This movie is just pure junk and if you want to see it see it in the movie theater, then come to the theater. It's bad entertainment. Don't wait for it to hit your head with a brick...unless you just want to laugh out loud at
# --------------------------------------------------
# Rank 14 - Reward: 4.4375
# Sample: I watched a movie and I got the feeling I was watching a musical rather than a film.<br /><br />The acting (in this movie) was awful. The actors had a bad feeling when they were acting and that was the only reason that I sat through the
# --------------------------------------------------
# Rank 15 - Reward: 4.2422
# Sample: In my opinion, the movie was a disaster, despite the fact it was filmed in very low budget. The cinematography was horrible and some of the shots looked like they had been shot using cheap video effects.<br /><br />When you think of "The Godfather III
# --------------------------------------------------
# Rank 16 - Reward: 4.2266
# Sample: I watched a movie and still can't feel my face!<br /><br />I would have preferred something more satisfying but the script was so rushed it left me thinking too much! The pacing is flat as hell and everything is not moving at the same time, its
# --------------------------------------------------
# Rank 17 - Reward: 4.1797
<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# --------------------------------------------------
# Rank 32 - Reward: 2.0781
# Sample: My impression of the movie is that all the characters are interesting, just not so different from each other. The main character is annoying at times, his only redeeming feature is for being kind to it (he is a cute-looking guy, not a creepy guy...) and
# --------------------------------------------------
# Rank 33 - Reward: 1.9678
# Sample: After watching the film, I feel sorry for many involved but, the film deserves praise not to be taken as a proof of a genius's genius, it's just an insult to the talent and good production values of the filmmaker.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# --------------------------------------------------
# Rank 34 - Reward: 1.8281
# Sample: After watching the film, I feel I need to make another one. I was bored while watching this one. Now, I'm bored forever. I am bored again.<br /><br />Why did you pay for it? Why even bother to see it? I would love to
# --------------------------------------------------
# Rank 35 - Reward: 1.8008
# Sample: After watching the film, I feel certain that I will not get all of the other good reviews because the film only offers good, un-boring performances. <br /><br />Don't let the title fool you! Watch this movie!<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# --------------------------------------------------
# Rank 36 - Reward: 1.7861
# Sample: This movie is a very good, but bad, sequel to "The Devil's Daughter" (1978). After the tragic and overbearing "Dirty Harry" (1970), "The Devil's Daughter" is directed by the beautiful Catherine Marple, who did an
# --------------------------------------------------
# Rank 37 - Reward: 1.7803
# Sample: The film was shot in the old, decaying city. In the background in the old factory, you could see the town's population - it was all too easy to see a lot of the old people lying around. It was not easy to see the entire audience on
# --------------------------------------------------
# Rank 38 - Reward: 1.3936
# Sample: In my opinion, the movie is a bit of a "no-brainer", as I found it impossible to enjoy it any more. I think that in the end, it's good for a laugh, but there are parts that irritate at the very end that make the ending
# --------------------------------------------------
# Rank 39 - Reward: 1.1240
# Sample: In my opinion, the movie is a bit weird for such a good premise. I watched it thinking that this movie would be so bad, and when I saw the trailer for this movie, the thing that I was most moved by was the fact that it would actually be funny,
# --------------------------------------------------
# Rank 40 - Reward: 0.7178
# Sample: I watched a movie and I just saw an old woman in a gown, and that was just fine. It was just so old with all the weirdness about who you want to be: an old school girl with nothing, an old housewife, a doctor, a nurse
# --------------------------------------------------
# Rank 41 - Reward: 0.3093
# Sample: In my opinion, the movie is over the top with every little thing it touches. We're left with a scene where a woman is running away with a dead chicken, but only when the killer throws her a bone. This was shot in an abandoned hospital, so it would be
# --------------------------------------------------
# Rank 42 - Reward: 0.0075
# Sample: After watching the film, I feel embarrassed to admit that it is supposed to be very realistic in the first place, with lots of symbolism in it, which is really the key to the film.<br /><br />In the end, what exactly is going on is beyond me.
# --------------------------------------------------
# Rank 43 - Reward: -0.0271
# Sample: This movie is about two sisters (one of whom is a cop) who are at the school when a man named Donald is involved. Their son (the man is Donald's own son) (who is also not in the school for the school day) is killed
# --------------------------------------------------
# Rank 44 - Reward: -0.2292
# Sample: I watched a movie and the fact of the matter is, you will feel sorry for him in the long run for having made movies like that.<br /><br />And what will happen with the rest? Will there be enough good movies to keep the people that enjoyed this
# --------------------------------------------------
# Rank 45 - Reward: -0.3877
# Sample: The dialogue in the film can seem clichéd at times, and the way in which the main characters (as well as the actors themselves) communicate with each other through dialogue (or just by saying "you know it, I know it" etc. is not an exaggeration)
# --------------------------------------------------
# Rank 46 - Reward: -0.5088
# Sample: The dialogue in the film could have been a little different. So they decided to add more to what appeared to be a good story along the lines of 'The Thing' starring Jane Fonda or 'The Wolfman'. The way the main character was portrayed in the film is
# --------------------------------------------------
# Rank 47 - Reward: -0.5283
# Sample: In my opinion, the movie had potential and if you are trying to create drama then try it in a less dramatic way. In the movie the main character is being chased and he has three legs (one big leg, one short leg) and if he is kept alive he will
# --------------------------------------------------
# Rank 48 - Reward: -0.6323
# Sample: After watching the film, I feel as though my soul has been broken and my body is going nowhere. The fact that every scene in it is so unbelievable, especially the moment when one of those actors says "Goodbye, my dear" in a small way, sounds like the voice
# --------------------------------------------------
# Rank 49 - Reward: -0.6519
# Sample: My impression of the movie is that it was the first to be filmed in the United Kingdom,and is based on the book. The movie isn't even called 'The First Movie', it is called 'The First Movie, which sounds like a cheap English movie. But what it
# --------------------------------------------------
# Rank 50 - Reward: -0.9365
# Sample: My impression of the movie is that the plot line is about the two main characters of Yakuza's main character who are killed in the first story. The end leads them to something called Final Doom and the end of this story, however the end is more about revenge and of
# --------------------------------------------------
# Rank 51 - Reward: -1.0283
# Sample: I watched a movie and I still think that, in this day and age, movies like "Wicked", "American Horror","The Thing", etc. still make a lot of people sad with that title.<br /><br />Even more concerning, some people simply
# --------------------------------------------------
# Rank 52 - Reward: -1.0439
# Sample: The dialogue in the film is more subtle than in Troma's other films with the main character "A." He isn't the villain, but instead, he's a person who has been given one reason to leave the United States for work. In the film, he has
# --------------------------------------------------
# Rank 53 - Reward: -1.1211
# Sample: The dialogue in the film seems rather corny, and I cannot understand why someone like me didn't catch the final scenes of the movie on TV, a show which makes you think maybe this wasn't the case.<br /><br />The film is filled with humor,
# --------------------------------------------------
# Rank 54 - Reward: -1.2227
# Sample: In my opinion, the movie did a fairly decent job, the action was well paced and the pace a little slow, but the overall atmosphere was much like real life that had nothing to do with it. If you are a fan of bad movies, your not going to be disappointed
# --------------------------------------------------
# Rank 55 - Reward: -1.2881
# Sample: The film was released in Germany in 1971 where it was made after Nazi Germany fell.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# --------------------------------------------------
# Rank 56 - Reward: -1.2969
# Sample: After watching the film, I feel a little cheated, because this is the only time I have ever seen or listened to such a movie so I'm willing to watch it over and over again. I do have to confess to a couple of things that happened, and I just felt a
# --------------------------------------------------
# Rank 57 - Reward: -1.3477
# Sample: My impression of the movie is that it was written by a person who had been married for 45 years in Germany, at the same time as an Austrian who had been living at the home where you first watched it, and is now living in Paris. It doesn't take another three
# --------------------------------------------------
# Rank 58 - Reward: -1.4658
# Sample: The film was written by Joe Cinco, the "King of English Movies". In the mid 1930's, Joe would be in the movie business, working as an accountant for a small company. After having learned what the film was about he decided to make "
# --------------------------------------------------
# Rank 59 - Reward: -1.5586
# Sample: The film was in the same frame as a film that appeared in the late 1980s and made its way on to the big screen. The other members included James Taylor (The Black List), a former TV detective now working for a drug dealer, as well as Peter
# --------------------------------------------------
# Rank 60 - Reward: -1.7031
# Sample: I watched a movie and it seemed a little dated. So it's been a while since I have said something more...the one movie to see is a thriller.<br /><br />A few people liked it because it made me forget and let me ask, why don
# --------------------------------------------------
# Rank 61 - Reward: -1.7568
# Sample: My impression of the movie is that the characters were all too real as far as the story went. <br /><br />I guess I would have been left with a headache and a bad headache over getting past the stupid action sequences. The movie was well done and the actors
# --------------------------------------------------
# Rank 62 - Reward: -1.7715
# Sample: In my opinion, the movie starts with an awkward little story that makes a bad movie, but the ending also makes a good movie and a good movie. I would recommend this movie to any girl. It's an hour long enough to complete any course of study. If you are
# --------------------------------------------------
# Rank 63 - Reward: -1.8604
# Sample: The film was about a man named Thomas Cates (Humphrey Bogart) who has the ability to use his powers to control people at will. Because of this he is able to create large, and seemingly endless, pools of fire, to which he draws
# --------------------------------------------------
# Rank 64 - Reward: -1.8633
# Sample: The film was released as part of a trilogy in 1997 under the title Dark Horse, which was followed by another trilogy that did not feature the original Dark Horse trilogy but also the "Dark Knight Returns" trilogy as well called, "The Dark Knight & the Dark Knight
# --------------------------------------------------
# Rank 65 - Reward: -1.8809
# Sample: The dialogue in the film was very good, along with the rest of the actors. A few lines were too hard to follow, so I just watched them again with one of my friends and I had to write it up in the book for the movie.<|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# --------------------------------------------------
# Rank 66 - Reward: -1.9736
# Sample: The film was also given free release to a number of Japanese indie films and was one of only a few recent ones released in North America so the plot is simple. When a young person dies suddenly, his family begins to gather and begin a search for him.<br
# --------------------------------------------------
# Rank 67 - Reward: -2.1309
# Sample: My impression of the movie is that it's so full of stereotypes that those of us who aren't a part of it will have to stop watching, because "I just want my kids to be treated humanely and I am no longer a person who likes this kind of treatment."
# --------------------------------------------------
# Rank 68 - Reward: -2.1484
# Sample: My impression of the movie is that for a guy that is very young who does everything for a living, this movie is very scary. That's exactly my intention, I wanted to have a bad laugh. But I wasn't scared, because as I watched it, I thought my
# --------------------------------------------------
# Rank 69 - Reward: -2.5176
# Sample: The dialogue in the film is in my opinion, the first of the kind to be heard by modern audiences (not the bad old-fashioned Hollywood equivalent of "Whispering With Your Mommy"). In all honesty, though, I really do feel that there is nothing of
# --------------------------------------------------
# Rank 70 - Reward: -2.5332
# Sample: The dialogue in the film was as close to a '70s-era as we would've liked from a horror film company.<br /><br />The music played a certain kind of 'comical' element. There is always a certain 'feel' to the sound
# --------------------------------------------------
# Rank 71 - Reward: -2.6289
# Sample: This movie is very good and will not make the world any more predictable. We see a young man (who, unlike the bad guys, does not have a clue that he's being treated here) coming to the aid of a child who seems to be in need
# --------------------------------------------------
# Rank 72 - Reward: -2.6836
# Sample: My impression of the movie is that at least the movie had something fun to do and a nice atmosphere to get a reaction to the characters. This is not only because the characters were nice, but because it is realistic. The plot is interesting but the characters are not. So this
# --------------------------------------------------
# Rank 73 - Reward: -2.7715
# Sample: My impression of the movie is pretty good. The plot may not appeal to everyone, but as a movie there would have to be some sort of theme. My impression of the film is "G-Men". There are enough "g-men" in this movie that they become
# --------------------------------------------------
# Rank 74 - Reward: -2.9023
# Sample: The film was in fact meant for people who liked, or are willing to read stories that may be interesting for others, but will not be able to find a way to engage with it.<br /><br />I like Richard Quinn as a character that you will
<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# --------------------------------------------------
# Rank 106 - Reward: -4.8711
# Sample: The film was well directed and the actors were terrific, in fact it was hilarious.<br /><br />I had one great disappointment though. The photography was superb. The action sequences in the film were great and at times very realistic, without becoming too preachy
# --------------------------------------------------
# Rank 107 - Reward: -4.8750
# Sample: My impression of the movie is not that bad to start with.<br /><br />The acting is great; the character development is all outstanding; the script is well written; and the movie is very entertaining at times. I do regret not spending more time on the DVD.<
# --------------------------------------------------
# Rank 108 - Reward: -4.8906
# Sample: This movie is fun to watch. With all the good acting performances by everyone, the film really got you involved with the characters. Just watch it! If you like a good horror film that can entertain a lot, this will be your must see. It's like
# --------------------------------------------------
# Rank 109 - Reward: -4.9375
# Sample: After watching the film, I feel like I haven't been so disappointed in this film. For me, it takes a little too much to appreciate it. The cinematography is so stunning and it reminds me of high school films in my youth or my mid-20's. It should
# --------------------------------------------------
# Rank 110 - Reward: -5.0078
# Sample: After watching the film, I feel very satisfied with the film. It is one of the best action films I have ever seen. If you are a serious martial arts expert, and you get to see this film on DVD or Blu-Ray, it is really a fantastic experience. You
# --------------------------------------------------
# Rank 111 - Reward: -5.0391
# Sample: In my opinion, the movie succeeds because of the premise and overall story. I like Jaden Smith, and this movie is a must-see for anyone interested in Hollywood. It's so entertaining, it's fun at times...<br /><br />5 out of 10
# --------------------------------------------------
# Rank 112 - Reward: -5.0430
# Sample: This movie is full of great action, great dialogue and a great storyline by Michael Moore. The movie is very funny and I am sure this movie is one of the best parts of the movie.<br /><br />Now here is the thing I must say about
# --------------------------------------------------

# %% [markdown]
# # Stage 2: fine-tune the main model with RL
#
#
# For this tutorial, we will optimize GPT2 to produce positive IMDB movie reviews using the reward model you trained above.
#
# Unlike supervised fine-tuning, RL allows model to generate it's own sentences on each training step. Then, it calculates the reward of those specific sentences, and finally, updates the model to increase the probability of sentences with high reward.
#
# Thus, each RLHF consists of three stages: __Rollout__, __Evaluation__ and __Update__
#
# <div style="text-align: center">
# <img src='https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/gpt2_bert_training.png' width='600'>
#
# The update stage depends on the specific RL algorithm. We'll be using Proximal Policy Optimization, or [PPO](https://arxiv.org/abs/1707.06347), similarly to what was used for InstructGPT.
#
# Before we run those 3 stages, however, we need to create a dataset of "queries" - partial reviews in our case.

# %%
# Note: this code is specific to IMDB; you will need to re-write it for other tasks
imdb_for_rlhf = imdb.filter(lambda row: len(row['text']) > 200, batched=False)
imdb_for_rlhf = imdb_for_rlhf.remove_columns(['label'])
sample_length = trl.core.LengthSampler(2, 8)  # use the first 2-8 tokens as query

def select_query_and_tokenize(sample):
    query_ids = main_tokenizer.encode(sample["text"])[: sample_length()]
    sample["query"] = main_tokenizer.decode(query_ids)  # query is the only required column
    sample["input_ids"] = query_ids  # to avoid re-tokenizing later
    return sample  # we do not need the rest - it will be generated by the model

imdb_for_rlhf = imdb_for_rlhf.map(select_query_and_tokenize, batched=False)
imdb_for_rlhf.set_format(type="torch")
# Out:
# Filter:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/24895 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1168 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# Next, let's prepare your reward model to predict rewards on whatever reviews were generated. Note that we use plaintext reviews because main model uses a different tokenizer from the reward model.

# %%
from typing import List
def compute_reward(texts: List[str]) -> torch.Tensor:
  inputs = reward_tokenizer(texts, truncation=True, padding=True, return_tensors='pt').to(device)
  with torch.no_grad():
    return reward_model(**inputs).logits[:, 0]

# %%
compute_reward([imdb[45]['text'], imdb[16000]['text']])  # test on human-written reviews
# Out:
# tensor([ 4.9375, -4.8008], device='cuda:0')

# %% [markdown]
# Finally, we move to RL training. In this tutorial, we'll train LoRA adapters and not the full model.

# %%
import peft
peft_config = peft.LoraConfig(
    task_type=peft.TaskType.CAUSAL_LM, r=32, lora_alpha=32, lora_dropout=0.0, inference_mode=False
)

# reload main model as AutoModelForCausalLMWithValueHead - with an extra head needed for PPO
main_tokenizer = transformers.AutoTokenizer.from_pretrained("lvwerra/gpt2-imdb")
main_tokenizer.pad_token = main_tokenizer.eos_token

main_model = trl.AutoModelForCausalLMWithValueHead.from_pretrained("lvwerra/gpt2-imdb", device_map=device)
main_model = peft.get_peft_model(main_model, peft_config, adapter_name='default')
main_model.print_trainable_parameters()
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora.py:475: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# trainable params: 1,179,648 || all params: 125,620,225 || trainable%: 0.9390589771670923

# %% [markdown]
# Same as before, trl has a special type of trainer that minimize PPO-specific pseudo-loss. You can read more on this trainer [here](https://huggingface.co/docs/trl/main/en/ppo_trainer).

# %%
training_args = trl.PPOConfig(
    model_name=main_model.config._name_or_path,
    gradient_accumulation_steps=1,
    learning_rate=1.41e-5,
    batch_size=64,
    ppo_epochs=4,                 # PPO performs this many updates per training batch
)

ppo_trainer = trl.PPOTrainer(
    training_args, model=main_model.model, tokenizer=main_tokenizer,
    dataset=imdb_for_rlhf, data_collator=lambda data: dict((key, [d[key] for d in data]) for key in data[0])
)  # note: we pass main_model.model because PPOTrainer checks for one of several supported model types ...
# ... main_model.model is a model with adapters, which is supported. main_model itself is a wrapper that is not supported

# %%
from tqdm.auto import tqdm
max_steps = 50   # can be insufficient for some tasks - watch your learning curves
generation_kwargs = dict(
    min_length=-1, max_new_tokens=128, do_sample=True, top_k=0, top_p=1.0, pad_token_id=main_tokenizer.eos_token_id)
#                                  ^-- task-specific parameter!
with tqdm(enumerate(ppo_trainer.dataloader), total=max_steps) as progressbar:
  # note: ppo_trainer.dataloader is just a regular dataloader of queries, no RL-specific magic :)
  for epoch, batch in progressbar:
    if epoch >= max_steps:
        break

    # Rollout stage: generate continuations from batch queries using main_model
    response_tensors = ppo_trainer.generate(batch['input_ids'], **generation_kwargs)
    # ^-- list of tensors of token ids from main model tokenizer

    # de-tokenize responses to strings (since reward model uses a different tokenizer)
    batch["response"] = [main_tokenizer.decode(response.squeeze()) for response in response_tensors]
    # note: response_tensors already contain query tokens, so we don't need to add queries manually.
    # This may not be true for other tasks: check this manually by viewing batch["response"] and batch["query"]


    # Evaluation stage
    rewards = compute_reward(batch['response'])

    # Update stage
    stats = ppo_trainer.step(batch['input_ids'], response_tensors, list(rewards.split(1)))
    stats['rewards/mean'] = rewards.mean().item()

    print("-" * 30, 'STEP', epoch, '-' * 30)
    print(f'rewards/mean:\t{stats["rewards/mean"]:.9f}\t<---- average reward over this batch (higher=better, noisy)')
    print(f'ppo/returns/mean:\t{stats["ppo/returns/mean"]:.9f}\t<---- model-estimated average discounted reward')
    print(f'objective/kl:\t{stats["objective/kl"]:.9f}\t<---- how far we are from the original model (regularizer)')
    print()

    ppo_trainer.log_stats(stats, batch, list(rewards.split(1)))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# ------------------------------ STEP 0 ------------------------------
# rewards/mean:	-0.059726715	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.657784343	<---- model-estimated average discounted reward
# objective/kl:	0.000000000	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 1 ------------------------------
# rewards/mean:	0.185347557	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.537705779	<---- model-estimated average discounted reward
# objective/kl:	0.032045912	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 2 ------------------------------
# rewards/mean:	-0.095960736	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.533527374	<---- model-estimated average discounted reward
# objective/kl:	0.289549679	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 3 ------------------------------
# rewards/mean:	0.958246708	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.262020469	<---- model-estimated average discounted reward
# objective/kl:	0.580322146	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 4 ------------------------------
# rewards/mean:	0.901437521	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.057065468	<---- model-estimated average discounted reward
# objective/kl:	0.925238192	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 5 ------------------------------
# rewards/mean:	1.228144765	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.120696485	<---- model-estimated average discounted reward
# objective/kl:	0.960412025	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 6 ------------------------------
# rewards/mean:	0.495411396	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.103288069	<---- model-estimated average discounted reward
# objective/kl:	1.565097809	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 7 ------------------------------
# rewards/mean:	0.870986700	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.034951806	<---- model-estimated average discounted reward
# objective/kl:	3.510741472	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 8 ------------------------------
# rewards/mean:	1.212788820	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.225945175	<---- model-estimated average discounted reward
# objective/kl:	3.073452950	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 9 ------------------------------
# rewards/mean:	0.514466286	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.092925072	<---- model-estimated average discounted reward
# objective/kl:	2.542783260	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 10 ------------------------------
# rewards/mean:	1.348973274	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.349741995	<---- model-estimated average discounted reward
# objective/kl:	3.201669216	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 11 ------------------------------
# rewards/mean:	0.801103592	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.400875270	<---- model-estimated average discounted reward
# objective/kl:	2.273102760	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 12 ------------------------------
# rewards/mean:	0.996090889	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.449446559	<---- model-estimated average discounted reward
# objective/kl:	2.712553978	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 13 ------------------------------
# rewards/mean:	1.269214630	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.634265482	<---- model-estimated average discounted reward
# objective/kl:	4.153372765	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 14 ------------------------------
# rewards/mean:	1.616387367	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.670417190	<---- model-estimated average discounted reward
# objective/kl:	5.246665001	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 15 ------------------------------
# rewards/mean:	1.327825069	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.656956553	<---- model-estimated average discounted reward
# objective/kl:	5.625439644	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 16 ------------------------------
# rewards/mean:	1.244768143	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.543355465	<---- model-estimated average discounted reward
# objective/kl:	8.032430649	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 17 ------------------------------
# rewards/mean:	1.484397411	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.590178311	<---- model-estimated average discounted reward
# objective/kl:	7.890834808	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 18 ------------------------------
# rewards/mean:	1.464623928	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.553112745	<---- model-estimated average discounted reward
# objective/kl:	6.598479271	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 19 ------------------------------
# rewards/mean:	2.337577820	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.792191267	<---- model-estimated average discounted reward
# objective/kl:	8.830334663	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 20 ------------------------------
# rewards/mean:	1.247005224	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.668501318	<---- model-estimated average discounted reward
# objective/kl:	7.698148727	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 21 ------------------------------
# rewards/mean:	1.570495605	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.759698868	<---- model-estimated average discounted reward
# objective/kl:	6.953764915	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 22 ------------------------------
# rewards/mean:	1.362448096	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.678663492	<---- model-estimated average discounted reward
# objective/kl:	8.287647247	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 23 ------------------------------
# rewards/mean:	1.805861473	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.746977925	<---- model-estimated average discounted reward
# objective/kl:	8.507905960	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 24 ------------------------------
# rewards/mean:	1.594482422	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.858288586	<---- model-estimated average discounted reward
# objective/kl:	8.408131599	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 25 ------------------------------
# rewards/mean:	2.315959930	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.976881504	<---- model-estimated average discounted reward
# objective/kl:	9.992355347	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 26 ------------------------------
# rewards/mean:	2.189466000	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.999460459	<---- model-estimated average discounted reward
# objective/kl:	9.886258125	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 27 ------------------------------
# rewards/mean:	1.998247147	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.016469479	<---- model-estimated average discounted reward
# objective/kl:	10.709365845	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 28 ------------------------------
# rewards/mean:	1.627925873	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.810959160	<---- model-estimated average discounted reward
# objective/kl:	8.767446518	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 29 ------------------------------
# rewards/mean:	2.183230400	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.950800538	<---- model-estimated average discounted reward
# objective/kl:	8.354450226	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 30 ------------------------------
# rewards/mean:	2.293354034	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.038297176	<---- model-estimated average discounted reward
# objective/kl:	9.683156967	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 31 ------------------------------
# rewards/mean:	1.702750206	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.894012630	<---- model-estimated average discounted reward
# objective/kl:	9.977327347	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 32 ------------------------------
# rewards/mean:	1.433887959	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.830402255	<---- model-estimated average discounted reward
# objective/kl:	9.329777718	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 33 ------------------------------
# rewards/mean:	1.988206863	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.846577406	<---- model-estimated average discounted reward
# objective/kl:	9.639071465	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 34 ------------------------------
# rewards/mean:	2.446533680	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.041215897	<---- model-estimated average discounted reward
# objective/kl:	11.090600014	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 35 ------------------------------
# rewards/mean:	2.191526413	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.955733776	<---- model-estimated average discounted reward
# objective/kl:	9.664129257	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 36 ------------------------------
# rewards/mean:	2.541326523	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.094472647	<---- model-estimated average discounted reward
# objective/kl:	9.398645401	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 37 ------------------------------
# rewards/mean:	2.586218834	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.216159105	<---- model-estimated average discounted reward
# objective/kl:	9.865135193	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 38 ------------------------------
# rewards/mean:	1.912121177	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.090798855	<---- model-estimated average discounted reward
# objective/kl:	9.612990379	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 39 ------------------------------
# rewards/mean:	2.073024750	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.146467447	<---- model-estimated average discounted reward
# objective/kl:	10.288133621	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 40 ------------------------------
# rewards/mean:	2.229218483	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.140763998	<---- model-estimated average discounted reward
# objective/kl:	10.542680740	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 41 ------------------------------
# rewards/mean:	2.463256836	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.255466700	<---- model-estimated average discounted reward
# objective/kl:	10.132394791	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 42 ------------------------------
# rewards/mean:	2.375882149	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.224715948	<---- model-estimated average discounted reward
# objective/kl:	10.326032639	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 43 ------------------------------
# rewards/mean:	1.928408623	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.124504805	<---- model-estimated average discounted reward
# objective/kl:	10.486042023	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 44 ------------------------------
# rewards/mean:	2.372519016	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.201514721	<---- model-estimated average discounted reward
# objective/kl:	10.890170097	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 45 ------------------------------
# rewards/mean:	2.337822914	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.198809028	<---- model-estimated average discounted reward
# objective/kl:	11.141392708	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 46 ------------------------------
# rewards/mean:	2.272308350	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.134224415	<---- model-estimated average discounted reward
# objective/kl:	11.078124046	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 47 ------------------------------
# rewards/mean:	3.154449463	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.459279060	<---- model-estimated average discounted reward
# objective/kl:	12.171660423	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 48 ------------------------------
# rewards/mean:	2.317012787	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.188878059	<---- model-estimated average discounted reward
# objective/kl:	12.154869080	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 49 ------------------------------
# rewards/mean:	2.397510529	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.274286985	<---- model-estimated average discounted reward
# objective/kl:	11.787188530	<---- how far we are from the original model (regularizer)

# %% [markdown]
# ## Main assignment - <u>actually</u> train the model (8 points)
#
#
# Your main task for this week is to use the RLHF pipeline to train a model for a reward of your choice. Here's what you can choose from:
#
# __A. Toxicity fine-tuning:__ train the model to be less (or more!) toxic. For this task, you may use the data from [jigsaw toxic comments](https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge) and [lmsys/toxic-chat](https://huggingface.co/datasets/lmsys/toxic-chat),  or any other source. Alternatively, you may use toxicity scores from [oasst1](https://huggingface.co/datasets/OpenAssistant/oasst1).
#
#
# __B. Actual human feedback:__ use one of the existing datasets with pairwise human feedback to align your langauge model. You may use [anthropic's hh-rlhf](https://huggingface.co/datasets/Anthropic/hh-rlhf), [OpenAssistant dataset](https://huggingface.co/datasets/OpenAssistant/oasst1) or any other data you see fit. You may also turn the tables and train the model to [minimize](https://habrastorage.org/getpro/geektimes/post_images/ac7/2ad/827/ac72ad82767d4132164a4b6b76196c42.jpg) human preferences, as long as your model does not degrade to gibberish.
#
# __C. Controlled generation:__ Instead of training a reward model from human feedback, you may define the reward function as the text length (longer or shorter) or number of times the model uses specific words (e.g. "sorry", "apologize"). If you choose specific words, make sure the model generates them at least sometimes.
#
# __Alternatively,__ you may choose a different task. However, unless your task is very similar to one of the above, there is a chance that it will be **significantly** harder to solve, requiring orders of magnitude more compute and tuning. If you are in doubt, please ask the course staff. If they are AFK (again >.<), please prefer one of the recommended tasks.
#
#
# #### General tips & tricks
#
#
# Things to look out for:
# - during PPO stage, the reward model should be in eval mode (dropout disabled)
# - make sure max_length and max_new_tokens are enough for your chosen dataset - at least most of the time
# - when in doubt, view the data manually or inspect how the model performs on a few samples
#
#
# We highly recommend that you manually check the performance after each sub-stage:
# 1. when you assembled the pairwise dataset, inspect a couple of from of *your* dataset class and detokenize them. Make sure that you-the-human understand why one sample was accepted and the other - rejected. At least most of the time. This also lets you spot tokenization/truncation errors.
# 2. after you trained a reward model, measure how accurate this model is in isolation. If your reward model is poor, any subsequent RLHF will also fail.
# 3. once you've trained the main model with RL, ask it to generate examples and explore how well it does. If it produces an obviously bad output, check if the reward model assigns high reward to that output. If yes, reward model is the culprit; if no, it's a question of better/longer PPO training.
#
# __It is also a good idea to periodically print samples during training.__
#
# __When stuck, simplify the problem.__ If you've spent a several hours enchanting the reward model but it still won't budge, try switching to a simple subtask. For instance, if you're training on hh-rlhf, try limiting it the dataset to 10% of the shortest sequences - they are typically easier to learn.
#
#
# ## Assignment stages (and grading)
#
# Regardless of the specific task you chose, your solution needs to contain several parts that will be graded separately.
#
#
# #### Stage 1: reward model (4 points)
#
# Construct a dataset for training the reward model on your problem. Then, train a reward model on that dataset and evaluate how well can your model predict preferences on a hold-out (test) subset of your data.
#
# Please make sure that the part of your notebook where you evaluate reward model is clearly visible and reasonably easy to read. And for all that is holy, do not call it IMDB unless it actually **is** data of imdb movie reviews :)
#
# __Not all tasks require a reward model for later PPO fine-tuning.__ For instance, there's no reason to train a reward model if your reward equals sentence length. Likewise, toxicity reward can be estimated with a pre-trained toxicity classifier. __If your task does not require training a reward model, please train an unrelated model on [hh-rlhf](https://huggingface.co/datasets/Anthropic/hh-rlhf) as though you were solving assignment version B.__ This is for grading purposes only, you won't use this model for stage 2.
#
#
# #### Stage 2: RL fine-tuning (4 points)
#
# Once the reward model is ready - or you can compute rewards without a model - it is time to maximize that reward with PPO. Optionally, you may replace PPO with another RL algorithm (or unlikelihood learning scheme), but only if you're feeling adventurous.
#
#
# First, you need to choose a language model to be fine-tuned. You may choose any model, but make sure that your model **can** generate the data in your format. For instance, [Mistral-7B](https://huggingface.co/mistralai/Mistral-7B-v0.1) is a general purpose LM and may (or may not) need prompt engineering to generate chat assistant responses. For that reason, it is best if you **do not use `"lvwerra/gpt2-imdb"` unless you're generating only movie reviews**.
#
#
#
# There are two "difficulty modes" for this task:
# For the **easy mode**, use [gpt2-large](https://huggingface.co/gpt2-large) or [opt-1.3b](https://huggingface.co/facebook/opt-1.3b) with minimal code changes.
# If you want the **Hard mode:** use a larger (e.g. 7B) model in combination with `load_in_4bit` and LoRA, the same way we did last week.
# Some reasonable model choices are [LLaMA-7B](https://huggingface.co/Enoch/llama-7b-hf), [Falcon-7b](https://huggingface.co/tiiuae/falcon-7b), [Mistral-7B](https://huggingface.co/mistralai/Mistral-7B-v0.1) for general-purpose LM or [guanaco-7b](https://huggingface.co/timdettmers/guanaco-7b), [vicuna-7b](https://huggingface.co/lmsys/vicuna-7b-v1.5) for chat-based tasks, though there are many more (see [leaderboard](https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard)). In the hard mode, you will need to modify the training arguments to enable 4-bit fine-tuning. Furthermore, your experiments will take somewhat longer to complete. On the plus side, your model will produce significantly better results.
#
# __High reward is not enough!__ RL algorithms are famous for [cheating their reward functions](https://openai.com/research/faulty-reward-functions). To ensure that your model is actually doing what you want it to do, you will need some additional evaluation. To get the full grade, provide at least 20 side-by-side examples of your fine-tuned model vs original model predictions and a short summary.
#
# Alternatively, you may provide 5 examples and some extrinsic evaluation metric over many examples. For instance, you may use a different pre-trained toxicity score for option A. When dealing with human preferences, you may choose to [enlist actual humans](https://toloka.ai/) or [ask GPT4/Claude](https://arxiv.org/pdf/2304.03277.pdf) to compare your model's predictions. For task C, when optimizing for simple rewards like sentence lengths, it is enough to compare histograms of rewards (e.g. average lengths).
